# %% [markdown]
# # Satchel Example
#
# This notebook walks you through how to use the Satchel package and it's various features. The model is still being updated so expect things to change in the future.

# %%
from satchel.model import Satchel

# %%
# set up model run
model = Satchel(seed = 759)  # set a seed for reproduceability
results = model.simulate()
# Out:
# 100%|██████████| 10000/10000 [04:41<00:00, 35.55it/s]

# %% [markdown]
# ## Results
#
# The `SatchelResults` class that gets returned from a model run has a variety of built in plotting methods as well as a summary of the season results that you can break down by division

# %%
results.boxplot()
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1224eaf70>)

# %%
results.results_grid();

# %% [markdown]
# ## Division Results

# %%
results.nlwest
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 13  LAD   108.7885      53.2115       148        55  14.068410
# 22  SDP    99.6094      62.3906       148        36  14.560152
# 0   ARI    79.9232      82.0768       138        27  15.141454
# 24  SFG    69.6890      92.3110       129        21  15.021486
# 8   COL    53.8221     108.1779       116        14  14.007879
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 13             61.89               26.61              88.50           10.14
# 22             31.75               41.03              72.78            9.50
# 0               4.76               18.06              22.82            4.19
# 24              1.43                6.99               8.42            1.68
# 8               0.17                0.69               0.86            0.20
#
#     Win WS (%) Division
# 13        4.51  NL West
# 22        4.48  NL West
# 0         2.35  NL West
# 24        0.98  NL West
# 8         0.15  NL West

# %%
results.nlcentral
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 15  MIL    88.6573      73.3427       137        35  15.653369
# 25  STL    84.9585      77.0415       134        33  15.405587
# 4   CHC    81.7566      80.2434       141        27  15.501761
# 6   CIN    71.8321      90.1679       135        22  15.517925
# 21  PIT    65.0055      96.9945       123        21  15.210891
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 15             37.35               10.98              48.33           12.88
# 25             27.84               10.64              38.48           10.45
# 4              21.79                9.52              31.31            8.89
# 6               8.85                4.67              13.52            4.44
# 21              4.17                2.67               6.84            2.53
#
#     Win WS (%)    Division
# 15        7.27  NL Central
# 25        5.77  NL Central
# 4         5.66  NL Central
# 6         2.69  NL Central
# 21        1.68  NL Central

# %%
results.nleast
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 17  NYM    92.9539      69.0461       142        36  15.260349
# 1   ATL    92.4913      69.5087       138        38  15.195190
# 29  WSN    81.6811      80.3189       132        23  15.437371
# 20  PHI    80.4688      81.5312       134        27  15.493638
# 14  MIA    56.4406     105.5594       109        12  14.593820
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 17             37.09               20.12              57.21           10.98
# 1              34.89               20.59              55.48           11.57
# 29             14.37               13.42              27.79            6.02
# 20             12.94               12.89              25.83            6.08
# 14              0.71                1.12               1.83            0.45
#
#     Win WS (%) Division
# 17        5.73  NL East
# 1         5.85  NL East
# 29        3.39  NL East
# 20        3.61  NL East
# 14        0.27  NL East

# %%
results.alwest
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 10  HOU    92.5771      69.4229       142        32  15.182987
# 12  LAA    84.1098      77.8902       132        30  15.391778
# 19  OAK    80.3337      81.6663       132        29  15.475991
# 23  SEA    75.8291      86.1709       128        26  15.451368
# 27  TEX    57.9834     104.0166       118        16  14.622801
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 10             46.29               10.72              57.01           15.04
# 12             23.81               10.27              34.08            9.87
# 19             17.23                8.64              25.87            7.81
# 23             11.12                6.19              17.31            5.33
# 27              1.55                0.79               2.34            1.01
#
#     Win WS (%) Division
# 10        7.02  AL West
# 12        4.88  AL West
# 19        3.92  AL West
# 23        2.71  AL West
# 27        0.71  AL West

# %%
results.alcentral
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 16  MIN    97.1771      64.8229       146        38  15.179894
# 5   CHW    90.4993      71.5007       140        36  15.389766
# 7   CLE    77.9098      84.0902       137        25  15.506344
# 11  KCR    67.6404      94.3596       129        14  15.377761
# 9   DET    66.4969      95.5031       125        19  14.996776
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 16             51.22               14.81              66.03           13.47
# 5              31.36               17.62              48.98           10.62
# 7              10.31                9.44              19.75            4.79
# 11              3.76                3.61               7.37            2.18
# 9               3.35                2.42               5.77            2.04
#
#     Win WS (%)    Division
# 16        5.65  AL Central
# 5         5.21  AL Central
# 7         2.40  AL Central
# 11        1.18  AL Central
# 9         1.14  AL Central

# %%
results.aleast
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 18  NYY   100.4195      61.5805       147        41  14.871215
# 28  TOR    96.2083      65.7917       141        32  14.842107
# 26  TBR    92.3154      69.6846       147        36  15.211524
# 3   BOS    83.9767      78.0233       147        31  15.653142
# 2   BAL    58.4456     103.5544       113        13  14.376825
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 18             40.94               30.22              71.16            8.10
# 28             27.49               33.34              60.83            7.46
# 26             21.39               30.47              51.86            7.40
# 3               9.93               19.98              29.91            4.59
# 2               0.25                1.48               1.73            0.29
#
#     Win WS (%) Division
# 18        3.12  AL East
# 28        2.73  AL East
# 26        2.91  AL East
# 3         1.88  AL East
# 2         0.15  AL East

# %% [markdown]
# ## Most likely playoff matchups
#
# ### NL Wild Card

# %%
results.nlwc_matchups.head(10)
# Out:
#    Matchup  Probability
# 0  ATL-SDP       0.0663
# 1  NYM-SDP       0.0620
# 2  ARI-SDP       0.0506
# 3  ATL-LAD       0.0439
# 4  LAD-NYM       0.0412
# 5  PHI-SDP       0.0399
# 6  SDP-WSN       0.0389
# 7  MIL-SDP       0.0343
# 8  ARI-LAD       0.0314
# 9  SDP-STL       0.0287

# %% [markdown]
# ### AL Wild Card

# %%
results.alwc_matchups.head(10)
# Out:
#    Matchup  Probability
# 0  TBR-TOR       0.0678
# 1  NYY-TBR       0.0547
# 2  NYY-TOR       0.0501
# 3  BOS-TOR       0.0428
# 4  CHW-TOR       0.0371
# 5  CHW-NYY       0.0355
# 6  BOS-NYY       0.0352
# 7  BOS-TBR       0.0342
# 8  CHW-TBR       0.0312
# 9  MIN-TOR       0.0311

# %% [markdown]
# ### NLDS

# %%
results.nlds_matchups.head(10)
# Out:
#    Matchup  Probability
# 0  LAD-NYM      0.11430
# 1  ATL-LAD      0.10870
# 2  NYM-SDP      0.05945
# 3  ATL-SDP      0.05445
# 4  LAD-WSN      0.04385
# 5  LAD-PHI      0.04045
# 6  MIL-SDP      0.03520
# 7  MIL-STL      0.03125
# 8  SDP-STL      0.02655
# 9  CHC-MIL      0.02495

# %% [markdown]
# ### ALDS

# %%
results.alds_matchups.head(10)
# Out:
#    Matchup  Probability
# 0  HOU-NYY      0.09405
# 1  CHW-MIN      0.06750
# 2  HOU-TOR      0.06340
# 3  LAA-NYY      0.05035
# 4  HOU-TBR      0.05015
# 5  MIN-TOR      0.03895
# 6  MIN-TBR      0.03790
# 7  MIN-NYY      0.03675
# 8  NYY-OAK      0.03445
# 9  LAA-TOR      0.03205

# %% [markdown]
# ### NLCS

# %%
results.nlcs_matchups.head(10)
# Out:
#    Matchup  Probability
# 0  LAD-MIL       0.0495
# 1  LAD-SDP       0.0486
# 2  ATL-MIL       0.0439
# 3  MIL-NYM       0.0436
# 4  LAD-STL       0.0420
# 5  ATL-STL       0.0372
# 6  NYM-STL       0.0361
# 7  ATL-NYM       0.0347
# 8  CHC-LAD       0.0335
# 9  CHC-NYM       0.0290

# %% [markdown]
# ### ALCS

# %%
results.alcs_matchups.head(10)
# Out:
#    Matchup  Probability
# 0  HOU-MIN       0.0744
# 1  CHW-HOU       0.0589
# 2  LAA-MIN       0.0389
# 3  MIN-NYY       0.0333
# 4  CHW-LAA       0.0323
# 5  MIN-OAK       0.0315
# 6  NYY-TOR       0.0291
# 7  MIN-TOR       0.0274
# 8  CHW-NYY       0.0271
# 9  HOU-NYY       0.0245

# %% [markdown]
# ### World Series

# %%
results.ws_matchups.head(10)
# Out:
#    Matchup  Probability
# 0  HOU-MIL       0.0200
# 1  HOU-NYM       0.0190
# 2  ATL-HOU       0.0175
# 3  ATL-MIN       0.0171
# 4  MIL-MIN       0.0160
# 5  HOU-LAD       0.0153
# 6  HOU-STL       0.0150
# 7  MIN-NYM       0.0138
# 8  HOU-SDP       0.0138
# 9  MIN-STL       0.0135
