# %% [markdown]
# # Satchel Example
#
# This notebook walks you through how to use the Satchel package and it's various features. The model is still being updated so expect things to change in the future.

# %%
from satchel.model import Satchel

# %%
# set up model run
model = Satchel(seed = 759)  # set a seed for reproduceability
results = model.simulate()
# Out:
# 100%|██████████| 10000/10000 [04:46<00:00, 34.96it/s]

# %% [markdown]
# ## Results
#
# The `SatchelResults` class that gets returned from a model run has a variety of built in plotting methods as well as a summary of the season results that you can break down by division

# %%
results.boxplot()
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x120dae400>)

# %%
results.results_grid();

# %% [markdown]
# ## Division Results

# %%
results.nlwest
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 13  LAD   107.0718      54.9282       140        57  12.191953
# 22  SDP    96.0081      65.9919       142        45  12.840114
# 0   ARI    75.5950      86.4050       120        32  13.039071
# 24  SFG    72.4751      89.5249       119        26  12.985524
# 8   COL    58.7638     103.2362       107        19  12.402387
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 13             69.45               21.72              91.17           10.55
# 22             26.32               43.34              69.66            9.62
# 0               2.38               11.72              14.10            2.96
# 24              1.66                8.14               9.80            2.05
# 8               0.19                1.01               1.20            0.26
#
#     Win WS (%) Division
# 13        3.98  NL West
# 22        4.62  NL West
# 0         1.57  NL West
# 24        1.08  NL West
# 8         0.17  NL West

# %%
results.nlcentral
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 15  MIL    86.3383      75.6617       130        36  13.261434
# 25  STL    83.1948      78.8052       126        33  13.463632
# 4   CHC    79.1626      82.8374       131        27  13.311562
# 6   CIN    74.9340      87.0660       124        26  13.238443
# 21  PIT    66.1990      95.8010       116        25  13.237316
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 15             36.87                8.86              45.73           12.97
# 25             28.28                8.23              36.51           10.57
# 4              19.02                7.15              26.17            8.28
# 6              11.51                5.53              17.04            5.47
# 21              4.32                1.84               6.16            2.32
#
#     Win WS (%)    Division
# 15        6.85  NL Central
# 25        5.94  NL Central
# 4         4.81  NL Central
# 6         3.25  NL Central
# 21        1.55  NL Central

# %%
results.nleast
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 1   ATL    91.6991      70.3009       136        44  13.255796
# 17  NYM    91.2223      70.7777       136        40  13.196867
# 29  WSN    85.9570      76.0430       133        37  13.481459
# 20  PHI    81.1539      80.8461       132        34  13.420299
# 14  MIA    63.1807      98.8193       117        23  12.919704
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 1              33.61               22.88              56.49           10.15
# 17             32.94               22.47              55.41           10.04
# 29             20.45               20.17              40.62            8.51
# 20             11.95               14.98              26.93            5.40
# 14              1.05                1.96               3.01            0.85
#
#     Win WS (%) Division
# 1         4.69  NL East
# 17        4.87  NL East
# 29        4.23  NL East
# 20        2.91  NL East
# 14        0.53  NL East

# %%
results.alwest
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 10  HOU    92.6217      69.3783       138        45  13.101479
# 12  LAA    86.4365      75.5635       135        38  13.187159
# 19  OAK    79.8817      82.1183       137        37  13.295833
# 23  SEA    72.9890      89.0110       122        30  13.354644
# 27  TEX    63.7122      98.2878       109        22  13.059082
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 10             48.31               13.27              61.58           14.47
# 12             28.59               14.45              43.04           11.05
# 19             14.63               10.57              25.20            7.21
# 23              6.66                5.24              11.90            3.48
# 27              1.81                1.73               3.54            1.33
#
#     Win WS (%) Division
# 10        7.26  AL West
# 12        5.78  AL West
# 19        3.77  AL West
# 23        2.02  AL West
# 27        0.82  AL West

# %%
results.alcentral
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 16  MIN    94.5444      67.4556       137        43  13.281877
# 5   CHW    90.6415      71.3585       137        40  13.559512
# 7   CLE    81.2549      80.7451       126        33  13.589253
# 11  KCR    70.8118      91.1882       128        26  13.180044
# 9   DET    68.2388      93.7612       117        26  13.068652
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 16             47.19               17.93              65.12           12.70
# 5              33.21               20.54              53.75           10.38
# 7              13.51               13.37              26.88            6.16
# 11              3.59                4.81               8.40            2.01
# 9               2.50                3.74               6.24            1.71
#
#     Win WS (%)    Division
# 16        5.54  AL Central
# 5         4.97  AL Central
# 7         2.98  AL Central
# 11        1.10  AL Central
# 9         1.02  AL Central

# %%
results.aleast
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 18  NYY    96.7497      65.2503       140        48  13.062707
# 28  TOR    94.0097      67.9903       138        46  13.282487
# 26  TBR    88.0647      73.9353       136        39  13.286488
# 3   BOS    76.4381      85.5619       128        30  13.306993
# 2   BAL    60.6498     101.3502       111        23  12.585118
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 18             42.33               27.90              70.23            9.58
# 28             33.84               28.40              62.24            9.11
# 26             18.72               25.81              44.53            7.31
# 3               4.77               11.01              15.78            3.03
# 2               0.34                1.23               1.57            0.47
#
#     Win WS (%) Division
# 18        4.29  AL East
# 28        3.94  AL East
# 26        3.46  AL East
# 3         1.72  AL East
# 2         0.28  AL East

# %% [markdown]
# ## Most likely playoff matchups
#
# ### NL Wild Card

# %%
results.nlwc_matchups.head(10)
# Out:
#    Matchup  Probability
# 0  ATL-SDP       0.0790
# 1  NYM-SDP       0.0728
# 2  SDP-WSN       0.0671
# 3  PHI-SDP       0.0459
# 4  ATL-LAD       0.0390
# 5  LAD-NYM       0.0380
# 6  ARI-SDP       0.0346
# 7  LAD-WSN       0.0325
# 8  MIL-SDP       0.0277
# 9  LAD-PHI       0.0245

# %% [markdown]
# ### AL Wild Card

# %%
results.alwc_matchups.head(10)
# Out:
#    Matchup  Probability
# 0  CHW-NYY       0.0434
# 1  TBR-TOR       0.0418
# 2  NYY-TBR       0.0395
# 3  CHW-TOR       0.0371
# 4  CHW-TBR       0.0353
# 5  MIN-TOR       0.0344
# 6  MIN-NYY       0.0324
# 7  NYY-TOR       0.0301
# 8  MIN-TBR       0.0270
# 9  LAA-NYY       0.0264

# %% [markdown]
# ### NLDS

# %%
results.nlds_matchups.head(10)
# Out:
#    Matchup  Probability
# 0  ATL-LAD      0.11855
# 1  LAD-NYM      0.11220
# 2  LAD-WSN      0.07165
# 3  NYM-SDP      0.04450
# 4  ATL-SDP      0.04320
# 5  LAD-PHI      0.04105
# 6  MIL-SDP      0.03820
# 7  SDP-STL      0.02765
# 8  SDP-WSN      0.02640
# 9  MIL-STL      0.02480

# %% [markdown]
# ### ALDS

# %%
results.alds_matchups.head(10)
# Out:
#    Matchup  Probability
# 0  HOU-NYY      0.10125
# 1  HOU-TOR      0.08105
# 2  CHW-MIN      0.06945
# 3  LAA-NYY      0.06130
# 4  LAA-TOR      0.04870
# 5  HOU-TBR      0.04700
# 6  NYY-OAK      0.03260
# 7  MIN-TBR      0.03110
# 8  MIN-TOR      0.03065
# 9  MIN-NYY      0.03060

# %% [markdown]
# ### NLCS

# %%
results.nlcs_matchups.head(10)
# Out:
#    Matchup  Probability
# 0  LAD-MIL       0.0579
# 1  LAD-SDP       0.0505
# 2  LAD-STL       0.0433
# 3  ATL-MIL       0.0407
# 4  MIL-NYM       0.0369
# 5  CHC-LAD       0.0328
# 6  ATL-NYM       0.0324
# 7  ATL-STL       0.0315
# 8  NYM-STL       0.0307
# 9  MIL-WSN       0.0262

# %% [markdown]
# ### ALCS

# %%
results.alcs_matchups.head(10)
# Out:
#    Matchup  Probability
# 0  HOU-MIN       0.0635
# 1  CHW-HOU       0.0566
# 2  LAA-MIN       0.0478
# 3  MIN-NYY       0.0423
# 4  CHW-LAA       0.0353
# 5  CHW-NYY       0.0341
# 6  NYY-TOR       0.0335
# 7  MIN-TOR       0.0326
# 8  CLE-HOU       0.0286
# 9  CHW-TOR       0.0276

# %% [markdown]
# ### World Series

# %%
results.ws_matchups.head(10)
# Out:
#    Matchup  Probability
# 0  HOU-MIL       0.0196
# 1  MIL-MIN       0.0182
# 2  ATL-HOU       0.0168
# 3  LAA-MIL       0.0160
# 4  MIN-STL       0.0156
# 5  HOU-LAD       0.0156
# 6  HOU-STL       0.0154
# 7  HOU-SDP       0.0136
# 8  LAA-NYM       0.0134
# 9  HOU-NYM       0.0133

# %% [markdown]
# # Probability of Winning the World Series

# %%
results.season_summary[['Team', 'Win WS (%)']].sort_values('Win WS (%)', ascending=False)
# Out:
#    Team  Win WS (%)
# 10  HOU        7.26
# 15  MIL        6.85
# 25  STL        5.94
# 12  LAA        5.78
# 16  MIN        5.54
# 5   CHW        4.97
# 17  NYM        4.87
# 4   CHC        4.81
# 1   ATL        4.69
# 22  SDP        4.62
# 18  NYY        4.29
# 29  WSN        4.23
# 13  LAD        3.98
# 28  TOR        3.94
# 19  OAK        3.77
# 26  TBR        3.46
# 6   CIN        3.25
# 7   CLE        2.98
# 20  PHI        2.91
# 23  SEA        2.02
# 3   BOS        1.72
# 0   ARI        1.57
# 21  PIT        1.55
# 11  KCR        1.10
# 24  SFG        1.08
# 9   DET        1.02
# 27  TEX        0.82
# 14  MIA        0.53
# 2   BAL        0.28
# 8   COL        0.17
