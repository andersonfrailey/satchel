# %% [markdown]
# # Satchel Example
#
# This notebook walks you through how to use the Satchel package and it's various features. The model is still being updated so expect things to change in the future.

# %%
from satchel.model import Satchel
from satchel import utils, SatchelComparison
from satchel.schedules.createschedule import YEAR

# %%
# set up model run
model = Satchel(seed=759, use_current_results=False)  # set a seed for reproduceability
results = model.simulate()
# Out:
# 100%|██████████| 20000/20000 [01:45<00:00, 189.02it/s]

# %% [markdown]
# ## Results
#
# The `SatchelResults` class that gets returned from a model run has a variety of built in plotting methods as well as a summary of the season results that you can break down by division

# %%
results.boxplot()
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  <Axes: title={'center': 'Distribution of Total Wins'}, ylabel='Wins'>)

# %%
results.results_grid()

# %%
results.results_scatter("HOU", offset=1000)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Wins'>)

# %% [markdown]
# Use the `season_percentile` method to see what percentile of the wins distribution a team's season will fall.

# %%
results.season_percentile(team="HOU", wins=90)
# Out:
# 0.67955

# %% [markdown]
# ## Division Results

# %%
results.nlwest
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins    St.Dev  \
# 14  LAD         98           64       133        63  9.097519
# 22  SDP         84           78       123        40  9.457928
# 0   ARI         81           81       122        46  9.424543
# 24  SFG         77           85       114        41  9.489436
# 9   COL         61          101       103        28  9.038427
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 14             76.22               17.18              93.40           31.34
# 22             12.00               36.70              48.70            5.87
# 0               7.42               29.14              36.56            4.05
# 24              4.28               20.00              24.28            2.12
# 9               0.08                0.77               0.85            0.03
#
#     Win WS (%) Division
# 14       18.93  NL West
# 22        2.77  NL West
# 0         1.88  NL West
# 24        0.90  NL West
# 9         0.01  NL West

# %%
results.nlcentral
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins    St.Dev  \
# 5   CHC         84           78       120        48  9.432180
# 16  MIL         83           79       123        49  9.445540
# 7   CIN         79           83       116        43  9.469797
# 21  PIT         77           85       112        43  9.431953
# 25  STL         75           87       114        41  9.435117
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 5              33.96               19.09              53.04            7.12
# 16             29.59               18.93              48.52            6.43
# 7              15.42               15.00              30.41            2.93
# 21             12.11               12.72              24.82            2.15
# 25              8.92               10.02              18.95            1.59
#
#     Win WS (%)    Division
# 5         3.52  NL Central
# 16        3.02  NL Central
# 7         1.31  NL Central
# 21        0.95  NL Central
# 25        0.63  NL Central

# %%
results.nleast
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins    St.Dev  \
# 2   ATL         89           73       128        46  9.366314
# 18  NYM         88           74       120        54  9.349209
# 20  PHI         87           75       127        45  9.370770
# 15  MIA         74           88       117        38  9.429300
# 29  WSN         71           91       111        33  9.383597
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 2              36.23               33.73              69.96           13.35
# 18             31.56               34.31              65.88           11.62
# 20             26.75               34.25              60.99            9.56
# 15              3.50               11.34              14.83            1.21
# 29              1.97                6.83               8.79            0.65
#
#     Win WS (%) Division
# 2         7.08  NL East
# 18        6.05  NL East
# 20        4.67  NL East
# 15        0.47  NL East
# 29        0.27  NL East

# %%
results.alwest
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins    St.Dev  \
# 23  SEA         87           75       121        49  9.452781
# 11  HOU         85           77       121        48  9.421183
# 27  TEX         81           81       117        45  9.454224
# 1   ATH         77           85       113        42  9.499278
# 13  LAA         72           90       105        38  9.406813
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 23             40.12               22.13              62.24           12.69
# 11             29.72               23.23              52.95            8.88
# 27             17.18               18.98              36.16            4.87
# 1               9.62               13.25              22.87            2.64
# 13              3.36                6.40               9.77            0.88
#
#     Win WS (%) Division
# 23        6.33  AL West
# 11        4.28  AL West
# 27        2.21  AL West
# 1         1.10  AL West
# 13        0.26  AL West

# %%
results.alcentral
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins    St.Dev  \
# 10  DET         83           79       124        51  9.414261
# 12  KCR         83           79       119        43  9.467504
# 17  MIN         81           81       119        43  9.456036
# 8   CLE         76           86       117        44  9.463329
# 6   CHW         70           92       107        38  9.345250
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 10             31.11               16.54              47.65            6.98
# 12             31.36               16.28              47.64            7.34
# 17             22.89               15.25              38.15            5.22
# 8              11.08                9.83              20.91            2.36
# 6               3.55                4.15               7.69            0.52
#
#     Win WS (%)    Division
# 10        3.20  AL Central
# 12        3.23  AL Central
# 17        2.32  AL Central
# 8         0.88  AL Central
# 6         0.18  AL Central

# %%
results.aleast
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins    St.Dev  \
# 19  NYY         88           74       125        52  9.373765
# 28  TOR         88           74       125        51  9.443062
# 4   BOS         86           76       122        47  9.481299
# 3   BAL         85           77       123        46  9.486546
# 26  TBR         78           84       118        43  9.422303
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 19             27.13               35.40              62.53           13.03
# 28             29.10               35.29              64.39           13.71
# 4              20.20               33.52              53.72            9.86
# 3              17.62               31.91              49.54            8.21
# 26              5.93               17.84              23.78            2.80
#
#     Win WS (%) Division
# 19        6.61  AL East
# 28        7.13  AL East
# 4         4.76  AL East
# 3         3.97  AL East
# 26        1.09  AL East

# %% [markdown]
# ## Most likely playoff matchups
#
# ### NL Wild Card

# %%
results.nl_wild_card_1.head(10)
# Out:
#    Matchup  Probability
# 0  NYM-SDP      0.04370
# 1  ATL-SDP      0.04200
# 2  PHI-SDP      0.03805
# 3  NYM-PHI      0.03700
# 4  ATL-PHI      0.03360
# 5  ARI-SDP      0.03270
# 6  ARI-ATL      0.02990
# 7  ATL-NYM      0.02975
# 8  ARI-NYM      0.02830
# 9  ARI-PHI      0.02720

# %%
results.playoff_matchups
# Out:
#       NL Wild Card 1 NL WC 1 Champ NL Wild Card 2 WC 2 Champ   NLDS 1  \
# 0            ARI-PIT           PIT        SDP-SFG        SEA  ATL-PIT
# 1            CHC-LAD           LAD        ATL-NYM        CHW  CIN-LAD
# 2            MIL-SDP           SDP        PHI-PIT        NYY  LAD-SDP
# 3            ATL-WSN           WSN        NYM-PIT        BAL  PHI-WSN
# 4            NYM-PHI           NYM        MIL-SFG        BAL  ATL-NYM
# ...              ...           ...            ...        ...      ...
# 19995        LAD-MIL           MIL        ARI-SDP        NYY  ATL-MIL
# 19996        ARI-PHI           ARI        SFG-STL        HOU  ARI-NYM
# 19997        LAD-NYM           LAD        CHC-MIL        CLE  ATL-LAD
# 19998        PHI-WSN           PHI        PIT-STL        CHW  LAD-PHI
# 19999        PIT-SDP           PIT        ATL-PHI        TOR  LAD-PIT
#
#       NLDS 1 Champ   NLDS 2 NLDS 2 Champ     NLCS NL Champ  ... AL WC 1 Champ  \
# 0              ATL  SFG-STL          SFG  ATL-SFG      ATL  ...           KCR
# 1              CIN  NYM-SDP          NYM  CIN-NYM      NYM  ...           BAL
# 2              LAD  CHC-PHI          CHC  CHC-LAD      CHC  ...           BOS
# 3              PHI  LAD-NYM          LAD  LAD-PHI      LAD  ...           TEX
# 4              ATL  LAD-SFG          SFG  ATL-SFG      ATL  ...           ATH
# ...            ...      ...          ...      ...      ...  ...           ...
# 19995          ATL  ARI-PIT          ARI  ARI-ATL      ATL  ...           TEX
# 19996          NYM  LAD-SFG          LAD  LAD-NYM      NYM  ...           NYY
# 19997          LAD  ARI-CHC          ARI  ARI-LAD      ARI  ...           HOU
# 19998          LAD  NYM-PIT          PIT  LAD-PIT      LAD  ...           BOS
# 19999          LAD  CIN-PHI          CIN  CIN-LAD      CIN  ...           TEX
#
#       AL Wild Card 2   ALDS 1 ALDS 1 Champ   ALDS 2 ALDS 2 Champ     ALCS  \
# 0            MIN-SEA  CLE-KCR          KCR  SEA-TOR          TOR  KCR-TOR
# 1            BOS-CHW  ATH-BAL          BAL  CHW-NYY          CHW  BAL-CHW
# 2            NYY-TEX  BAL-BOS          BOS  KCR-NYY          NYY  BOS-NYY
# 3            BAL-SEA  CLE-TEX          CLE  BAL-HOU          BAL  BAL-CLE
# 4            BAL-CHW  ATH-BOS          ATH  BAL-HOU          BAL  ATH-BAL
# ...              ...      ...          ...      ...          ...      ...
# 19995        NYY-TOR  MIN-TEX          TEX  NYY-SEA          SEA  SEA-TEX
# 19996        DET-HOU  NYY-TOR          NYY  HOU-MIN          HOU  HOU-NYY
# 19997        CHW-CLE  HOU-SEA          SEA  CLE-NYY          NYY  NYY-SEA
# 19998        BAL-CHW  BOS-TBR          BOS  CHW-HOU          CHW  BOS-CHW
# 19999        MIN-TOR  SEA-TEX          TEX  BAL-TOR          TOR  TEX-TOR
#
#       AL Champ World Series WS Winner
# 0          TOR      ATL-TOR       TOR
# 1          BAL      BAL-NYM       NYM
# 2          NYY      CHC-NYY       CHC
# 3          BAL      BAL-LAD       BAL
# 4          BAL      ATL-BAL       ATL
# ...        ...          ...       ...
# 19995      TEX      ATL-TEX       ATL
# 19996      HOU      HOU-NYM       HOU
# 19997      NYY      ARI-NYY       NYY
# 19998      BOS      BOS-LAD       BOS
# 19999      TOR      CIN-TOR       TOR
#
# [20000 rows x 21 columns]

# %%
results.nl_wild_card_2.head(10)
# Out:
#    Matchup  Probability
# 0  CHC-MIL      0.03870
# 1  ATL-NYM      0.02615
# 2  CHC-CIN      0.02525
# 3  ATL-PHI      0.02480
# 4  CHC-PHI      0.02460
# 5  CHC-NYM      0.02375
# 6  CIN-MIL      0.02235
# 7  ATL-CHC      0.02235
# 8  CHC-SDP      0.02210
# 9  MIL-NYM      0.02190

# %% [markdown]
# ### AL Wild Card

# %%
results.al_wild_card_1.head(10)
# Out:
#    Matchup  Probability
# 0  NYY-TOR      0.03875
# 1  BOS-NYY      0.03790
# 2  BAL-NYY      0.03710
# 3  BOS-TOR      0.03635
# 4  BAL-TOR      0.03495
# 5  BAL-BOS      0.03315
# 6  HOU-NYY      0.02375
# 7  SEA-TOR      0.02315
# 8  HOU-TOR      0.02245
# 9  NYY-SEA      0.02230

# %%
results.al_wild_card_2.head(10)
# Out:
#    Matchup  Probability
# 0  DET-KCR      0.02470
# 1  HOU-SEA      0.02410
# 2  DET-SEA      0.02160
# 3  DET-HOU      0.02105
# 4  DET-MIN      0.02085
# 5  KCR-MIN      0.02060
# 6  KCR-SEA      0.01930
# 7  HOU-KCR      0.01930
# 8  BOS-DET      0.01890
# 9  BOS-KCR      0.01775

# %% [markdown]
# ### NLDS

# %%
results.nlds_1.head(10)
# Out:
#    Matchup  Probability
# 0  LAD-SDP      0.10590
# 1  ARI-LAD      0.07095
# 2  LAD-NYM      0.06730
# 3  ATL-LAD      0.06675
# 4  LAD-PHI      0.06255
# 5  ATL-NYM      0.05665
# 6  ATL-PHI      0.04600
# 7  LAD-SFG      0.03890
# 8  NYM-PHI      0.03850
# 9  CHC-LAD      0.03000

# %%
results.nlds_2.head(10)
# Out:
#    Matchup  Probability
# 0  CHC-LAD      0.04655
# 1  ATL-CHC      0.04345
# 2  CHC-NYM      0.03985
# 3  LAD-MIL      0.03910
# 4  MIL-NYM      0.03860
# 5  ATL-MIL      0.03820
# 6  CHC-PHI      0.03440
# 7  MIL-PHI      0.03090
# 8  ATL-LAD      0.02770
# 9  LAD-NYM      0.02630

# %% [markdown]
# ### ALDS

# %%
results.alds_1.head(10)
# Out:
#    Matchup  Probability
# 0  NYY-TOR      0.07065
# 1  BOS-TOR      0.05365
# 2  BOS-NYY      0.05045
# 3  BAL-TOR      0.04565
# 4  HOU-SEA      0.04425
# 5  BAL-NYY      0.04195
# 6  BAL-BOS      0.03055
# 7  SEA-TOR      0.02770
# 8  NYY-SEA      0.02530
# 9  SEA-TEX      0.02390

# %%
results.alds_2.head(10)
# Out:
#    Matchup  Probability
# 0  KCR-SEA      0.03675
# 1  DET-SEA      0.03665
# 2  DET-HOU      0.02990
# 3  HOU-KCR      0.02935
# 4  MIN-SEA      0.02805
# 5  HOU-MIN      0.02340
# 6  KCR-NYY      0.02040
# 7  DET-TEX      0.02030
# 8  SEA-TOR      0.01985
# 9  KCR-TOR      0.01965

# %% [markdown]
# ### NLCS

# %%
results.nlcs.head(10)
# Out:
#    Matchup  Probability
# 0  ATL-LAD       0.1107
# 1  LAD-NYM       0.0946
# 2  LAD-PHI       0.0795
# 3  CHC-LAD       0.0588
# 4  LAD-MIL       0.0503
# 5  CIN-LAD       0.0252
# 6  ATL-NYM       0.0230
# 7  ATL-CHC       0.0230
# 8  LAD-SDP       0.0217
# 9  NYM-SDP       0.0206

# %% [markdown]
# ### ALCS

# %%
results.alcs.head(10)
# Out:
#    Matchup  Probability
# 0  SEA-TOR      0.04435
# 1  NYY-SEA      0.04065
# 2  HOU-TOR      0.03215
# 3  BOS-SEA      0.03195
# 4  HOU-NYY      0.02945
# 5  BAL-SEA      0.02885
# 6  KCR-TOR      0.02705
# 7  DET-NYY      0.02470
# 8  DET-TOR      0.02355
# 9  BOS-HOU      0.02340

# %% [markdown]
# ### World Series

# %%
results.world_series.head(10)
# Out:
#    Matchup  Probability
# 0  LAD-TOR      0.04270
# 1  LAD-NYY      0.04195
# 2  LAD-SEA      0.04040
# 3  BOS-LAD      0.03020
# 4  HOU-LAD      0.02785
# 5  BAL-LAD      0.02510
# 6  KCR-LAD      0.02355
# 7  DET-LAD      0.02200
# 8  ATL-SEA      0.01920
# 9  ATL-TOR      0.01700

# %% [markdown]
# # Probability of Winning the World Series

# %%
results.season_summary[["Team", "Win WS (%)"]].sort_values(
    "Win WS (%)", ascending=False
)
# Out:
#    Team  Win WS (%)
# 14  LAD       18.93
# 28  TOR        7.13
# 2   ATL        7.08
# 19  NYY        6.61
# 23  SEA        6.33
# 18  NYM        6.05
# 4   BOS        4.76
# 20  PHI        4.67
# 11  HOU        4.28
# 3   BAL        3.97
# 5   CHC        3.52
# 12  KCR        3.23
# 10  DET        3.20
# 16  MIL        3.02
# 22  SDP        2.77
# 17  MIN        2.32
# 27  TEX        2.21
# 0   ARI        1.88
# 7   CIN        1.31
# 1   ATH        1.10
# 26  TBR        1.09
# 21  PIT        0.95
# 24  SFG        0.90
# 8   CLE        0.88
# 25  STL        0.63
# 15  MIA        0.47
# 29  WSN        0.27
# 13  LAA        0.26
# 6   CHW        0.18
# 9   COL        0.01

# %% [markdown]
# ## Test the effects of a transaction
#
# Satchel has the ability to test what would happen if there were a trade. As an example, suppose the Cubs traded Dansby Swanson to the Dodgers for Mookie Betts at the trade deadline (yes, I know this is unrealistic).
#
# First, look up the IDs for each player.

# %%
print(utils.player_id_lookup("swanson", "dansby"))
print(utils.player_id_lookup("betts", "mookie"))
# Out:
# Gathering player lookup table. This may take a moment.
#   name_last name_first  key_fangraphs
# 0   swanson     dansby          18314
#   name_last name_first  key_fangraphs
# 0     betts     mookie          13611

# %% [markdown]
# Then set up the transaction dictionary and pass it into Satchel

# %%
transaction = {
    "18314": {"team": "LAD", "date": f"{YEAR}-07-30"},
    "13611": {"team": "CHC", "date": f"{YEAR}-07-30"},
}
model2 = Satchel(seed=759, use_current_results=False, transactions=transaction)
results2 = model2.simulate()
# Out:
# 100%|██████████| 20000/20000 [01:51<00:00, 179.40it/s]

# %% [markdown]
# Then use the `SatchelComparison` class to compare the results.

# %%
comp = SatchelComparison(results, results2)

# %%
comp.win_dist_chart(team="CHC", sim1_label="Base", sim2_label="Trade")

# %%
comp.win_dist_chart(team="LAD", sim1_label="Base", sim2_label="Trade")
