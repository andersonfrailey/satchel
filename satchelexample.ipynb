# %% [markdown]
# # Satchel Example
#
# This notebook walks you through how to use the Satchel package and it's various features. The model is still being updated so expect things to change in the future.

# %%
from satchel.model import Satchel

# %%
# set up model run
model = Satchel(seed = 759, use_current_results=False)  # set a seed for reproduceability
results = model.simulate()
# Out:
# 100%|██████████| 20000/20000 [01:58<00:00, 168.14it/s]

# %% [markdown]
# ## Results
#
# The `SatchelResults` class that gets returned from a model run has a variety of built in plotting methods as well as a summary of the season results that you can break down by division

# %%
results.boxplot()
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  <Axes: title={'center': 'Distribution of Total Wins'}, ylabel='Wins'>)

# %%
results.results_grid();

# %%
results.results_scatter('HOU', offset=1000)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Wins'>)

# %% [markdown]
# Use the `season_percentile` method to see what percentile of the wins distribution a team's season will fall.

# %%
results.season_percentile(team='HOU', wins=90)
# Out:
# 0.4246

# %% [markdown]
# ## Division Results

# %%
results.nlwest
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 13  LAD         95           67       131        53  10.353156
# 22  SDP         86           76       124        38  10.599120
# 0   ARI         84           78       124        44  10.568432
# 24  SFG         81           81       119        43  10.484970
# 8   COL         60          102       101        22   9.982309
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 13             54.53               28.33              82.86           21.05
# 22             19.62               35.00              54.63            7.75
# 0              14.87               31.52              46.39            6.12
# 24             10.85               27.46              38.31            4.33
# 8               0.12                0.92               1.04            0.07
#
#     Win WS (%) Division
# 13       11.96  NL West
# 22        3.86  NL West
# 0         2.94  NL West
# 24        2.10  NL West
# 8         0.01  NL West

# %%
results.nlcentral
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 25  STL         84           78       135        46  10.612103
# 4   CHC         83           79       121        42  10.600007
# 6   CIN         78           84       118        39  10.539925
# 15  MIL         78           84       127        40  10.574339
# 21  PIT         76           86       116        32  10.618300
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 25             33.24               17.32              50.57            6.54
# 4              26.89               17.00              43.90            5.20
# 6              13.79               12.11              25.90            2.34
# 15             15.18               12.87              28.05            2.70
# 21             10.90               10.12              21.02            1.67
#
#     Win WS (%)    Division
# 25        3.09  NL Central
# 4         2.33  NL Central
# 6         1.00  NL Central
# 15        1.09  NL Central
# 21        0.71  NL Central

# %%
results.nleast
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 1   ATL         98           64       132        57  10.190410
# 20  PHI         87           75       124        46  10.503760
# 17  NYM         83           79       122        43  10.605537
# 14  MIA         73           89       116        35  10.632513
# 29  WSN         64           98       107        30  10.175997
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 1              66.61               22.95              89.55           27.45
# 20             19.16               38.62              57.78            8.07
# 17             11.47               31.55              43.02            5.42
# 14              2.42               11.80              14.22            1.11
# 29              0.35                2.41               2.76            0.17
#
#     Win WS (%) Division
# 1        16.46  NL East
# 20        3.87  NL East
# 17        2.46  NL East
# 14        0.47  NL East
# 29        0.07  NL East

# %%
results.alwest
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 10  HOU         91           71       129        53  10.385740
# 23  SEA         86           76       127        44  10.615050
# 27  TEX         86           76       124        46  10.457806
# 12  LAA         76           86       119        35  10.575959
# 19  OAK         68           94       108        30  10.371496
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 10             44.47               28.54              73.02           16.63
# 23             23.32               29.55              52.87            8.46
# 27             25.30               29.69              55.00            8.63
# 12              5.49               12.70              18.19            1.70
# 19              1.42                4.35               5.76            0.41
#
#     Win WS (%) Division
# 10        8.44  AL West
# 23        3.96  AL West
# 27        4.12  AL West
# 12        0.66  AL West
# 19        0.11  AL West

# %%
results.alcentral
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 16  MIN         88           74       128        46  10.582763
# 7   CLE         84           78       126        40  10.549410
# 9   DET         76           86       115        38  10.587845
# 11  KCR         73           89       118        33  10.496570
# 5   CHW         68           94       110        31  10.370535
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 16             48.34               15.25              63.59           11.19
# 7              31.40               17.40              48.80            7.22
# 9              10.71                9.73              20.43            2.05
# 11              7.03                7.19              14.22            1.20
# 5               2.52                3.36               5.88            0.40
#
#     Win WS (%)    Division
# 16        5.32  AL Central
# 7         3.38  AL Central
# 9         0.85  AL Central
# 11        0.43  AL Central
# 5         0.12  AL Central

# %%
results.aleast
# Out:
#    Team  Mean Wins  Mean Losses  Max Wins  Min Wins     St.Dev  \
# 18  NYY         91           71       130        47  10.469266
# 28  TOR         86           76       131        44  10.630395
# 2   BAL         84           78       122        44  10.582967
# 26  TBR         84           78       124        43  10.552402
# 3   BOS         79           83       122        38  10.589831
#
#     Win Division (%)  Make Wild Card (%)  Make Playoffs (%)  Win League (%)  \
# 18             36.52               33.40              69.92           15.53
# 28             23.12               32.00              55.12            9.19
# 2              15.60               27.71              43.31            7.05
# 26             17.73               29.89              47.62            7.34
# 3               7.03               19.25              26.27            3.02
#
#     Win WS (%) Division
# 18        7.96  AL East
# 28        4.46  AL East
# 2         3.14  AL East
# 26        3.41  AL East
# 3         1.23  AL East

# %% [markdown]
# ## Most likely playoff matchups
#
# ### NL Wild Card

# %%
results.nl_wild_card_1.head(10)
# Out:
#    Matchup  Probability
# 0  PHI-SDP      0.04555
# 1  NYM-PHI      0.04155
# 2  LAD-PHI      0.03950
# 3  ARI-PHI      0.03645
# 4  ARI-SDP      0.03500
# 5  NYM-SDP      0.02960
# 6  PHI-SFG      0.02835
# 7  ATL-LAD      0.02780
# 8  ATL-SDP      0.02700
# 9  LAD-NYM      0.02690

# %%
results.nl_wild_card_2.head(10)
# Out:
#    Matchup  Probability
# 0  CHC-STL      0.03705
# 1  SDP-STL      0.02590
# 2  MIL-STL      0.02375
# 3  LAD-SDP      0.02300
# 4  PHI-STL      0.02240
# 5  ARI-STL      0.02195
# 6  LAD-STL      0.02185
# 7  NYM-STL      0.02175
# 8  ATL-PHI      0.02165
# 9  SFG-STL      0.02155

# %% [markdown]
# ### AL Wild Card

# %%
results.al_wild_card_1.head(10)
# Out:
#    Matchup  Probability
# 0  NYY-TOR      0.03000
# 1  NYY-TEX      0.02985
# 2  NYY-SEA      0.02985
# 3  HOU-NYY      0.02945
# 4  SEA-TEX      0.02875
# 5  NYY-TBR      0.02770
# 6  HOU-TOR      0.02725
# 7  TBR-TOR      0.02675
# 8  BAL-TOR      0.02550
# 9  TEX-TOR      0.02540

# %%
results.al_wild_card_2.head(10)
# Out:
#    Matchup  Probability
# 0  CLE-MIN      0.03670
# 1  MIN-TEX      0.02655
# 2  HOU-TEX      0.02630
# 3  MIN-TBR      0.02565
# 4  MIN-SEA      0.02535
# 5  HOU-SEA      0.02480
# 6  MIN-TOR      0.02465
# 7  MIN-NYY      0.02400
# 8  HOU-MIN      0.02400
# 9  BAL-MIN      0.02235

# %% [markdown]
# ### NLDS

# %%
results.nlds_1.head(10)
# Out:
#    Matchup  Probability
# 0  ATL-PHI      0.11670
# 1  ATL-LAD      0.07045
# 2  ATL-NYM      0.07015
# 3  LAD-SDP      0.06770
# 4  ARI-LAD      0.05265
# 5  ATL-SDP      0.04855
# 6  ARI-ATL      0.04210
# 7  LAD-SFG      0.03845
# 8  LAD-PHI      0.03565
# 9  ATL-SFG      0.03170

# %%
results.nlds_2.head(10)
# Out:
#    Matchup  Probability
# 0  LAD-STL      0.05715
# 1  ATL-STL      0.04640
# 2  CHC-LAD      0.04540
# 3  ATL-CHC      0.03945
# 4  ATL-LAD      0.02835
# 5  LAD-MIL      0.02720
# 6  ATL-MIL      0.02685
# 7  CIN-LAD      0.02355
# 8  SDP-STL      0.02350
# 9  PHI-STL      0.02320

# %% [markdown]
# ### ALDS

# %%
results.alds_1.head(10)
# Out:
#    Matchup  Probability
# 0  HOU-TEX      0.06120
# 1  NYY-TOR      0.05840
# 2  HOU-SEA      0.05730
# 3  NYY-TBR      0.04605
# 4  BAL-NYY      0.04275
# 5  HOU-NYY      0.03655
# 6  CLE-MIN      0.02980
# 7  SEA-TEX      0.02715
# 8  TBR-TOR      0.02585
# 9  HOU-TOR      0.02525

# %%
results.alds_2.head(10)
# Out:
#    Matchup  Probability
# 0  HOU-MIN      0.05330
# 1  MIN-NYY      0.03825
# 2  CLE-HOU      0.03760
# 3  MIN-TEX      0.03370
# 4  MIN-SEA      0.03250
# 5  MIN-TOR      0.02805
# 6  HOU-NYY      0.02665
# 7  CLE-NYY      0.02655
# 8  CLE-TEX      0.02425
# 9  MIN-TBR      0.02305

# %% [markdown]
# ### NLCS

# %%
results.nlcs.head(10)
# Out:
#    Matchup  Probability
# 0  ATL-LAD      0.15015
# 1  ATL-SDP      0.05725
# 2  ATL-STL      0.05030
# 3  LAD-PHI      0.04960
# 4  ARI-ATL      0.04370
# 5  ATL-CHC      0.03730
# 6  ATL-SFG      0.03145
# 7  LAD-STL      0.03010
# 8  LAD-NYM      0.02930
# 9  CHC-LAD      0.02675

# %% [markdown]
# ### ALCS

# %%
results.alcs.head(10)
# Out:
#    Matchup  Probability
# 0  HOU-NYY      0.06445
# 1  MIN-NYY      0.04180
# 2  HOU-MIN      0.04110
# 3  HOU-TOR      0.03985
# 4  NYY-TEX      0.03655
# 5  NYY-SEA      0.03335
# 6  HOU-TBR      0.03245
# 7  CLE-NYY      0.02935
# 8  MIN-TOR      0.02890
# 9  BAL-HOU      0.02870

# %% [markdown]
# ### World Series

# %%
results.world_series.head(10)
# Out:
#    Matchup  Probability
# 0  ATL-HOU      0.04620
# 1  ATL-NYY      0.04345
# 2  HOU-LAD      0.03630
# 3  LAD-NYY      0.03115
# 4  ATL-MIN      0.02985
# 5  ATL-TOR      0.02690
# 6  LAD-MIN      0.02425
# 7  ATL-TEX      0.02315
# 8  ATL-SEA      0.02315
# 9  ATL-TBR      0.02185

# %% [markdown]
# # Probability of Winning the World Series

# %%
results.season_summary[['Team', 'Win WS (%)']].sort_values('Win WS (%)', ascending=False)
# Out:
#    Team  Win WS (%)
# 1   ATL       16.46
# 13  LAD       11.96
# 10  HOU        8.44
# 18  NYY        7.96
# 16  MIN        5.32
# 28  TOR        4.46
# 27  TEX        4.12
# 23  SEA        3.96
# 20  PHI        3.87
# 22  SDP        3.86
# 26  TBR        3.41
# 7   CLE        3.38
# 2   BAL        3.14
# 25  STL        3.09
# 0   ARI        2.94
# 17  NYM        2.46
# 4   CHC        2.33
# 24  SFG        2.10
# 3   BOS        1.23
# 15  MIL        1.09
# 6   CIN        1.00
# 9   DET        0.85
# 21  PIT        0.71
# 12  LAA        0.66
# 14  MIA        0.47
# 11  KCR        0.43
# 5   CHW        0.12
# 19  OAK        0.11
# 29  WSN        0.07
# 8   COL        0.01
